# %% [markdown]
# # CampusIQ: Exploratory Data Analysis\nThis notebook explores the synthetic student dataset to understand distributions, correlations, and risk factors.

# %%
import pandas as pd\nimport numpy as np\nimport matplotlib.pyplot as plt\nimport seaborn as sns\nfrom data_pipeline.data_generator import generate_synthetic_data\n\nsns.set_style('whitegrid')\nplt.rcParams['figure.figsize'] = (12, 6)\n\n# Generate data\ndf = generate_synthetic_data(n_students=1000)\ndf.head()

# %% [markdown]
# ## Distribution Overview

# %%
# GPA Distribution by Dropout Status\nfig, axes = plt.subplots(1, 2, figsize=(14, 5))\n\nsns.histplot(data=df, x='current_gpa', hue='dropped_out', bins=30, ax=axes[0])\naxes[0].set_title('GPA Distribution by Dropout Status')\n\nsns.countplot(data=df, x='program', hue='dropped_out', ax=axes[1])\naxes[1].set_title('Dropouts by Program')\naxes[1].tick_params(axis='x', rotation=45)\n\nplt.tight_layout()\nplt.show()

# %% [markdown]
# ## Correlation Analysis

# %%
# Correlation heatmap\nnumeric_cols = ['current_gpa', 'attendance_rate', 'engagement_score', 'credits_earned', 'age', 'dropped_out']\ncorr = df[numeric_cols].corr()\n\nplt.figure(figsize=(10, 8))\nsns.heatmap(corr, annot=True, cmap='RdBu_r', center=0, vmin=-1, vmax=1)\nplt.title('Feature Correlation Matrix')\nplt.show()

# %% [markdown]
# ## Risk Factor Analysis

# %%
# Risk by demographic factors\nfig, axes = plt.subplots(1, 2, figsize=(14, 5))\n\n# Financial aid impact\naid_dropout = df.groupby('financial_aid')['dropped_out'].mean()\naid_dropout.plot(kind='bar', ax=axes[0], color=['skyblue', 'salmon'])\naxes[0].set_title('Dropout Rate by Financial Aid Status')\naxes[0].set_ylabel('Dropout Rate')\n\n# First generation impact\nfg_dropout = df.groupby('first_generation')['dropped_out'].mean()\nfg_dropout.plot(kind='bar', ax=axes[1], color=['lightgreen', 'orange'])\naxes[1].set_title('Dropout Rate by First Generation Status')\naxes[1].set_ylabel('Dropout Rate')\n\nplt.tight_layout()\nplt.show()
